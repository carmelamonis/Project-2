# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime as dt
from datetime import datetime
import calendar

#from config import db_user, db_password, db_host, db_port, db_name

# %%
old_data = pd.read_csv("Data/Mother Jones - Mass Shootings Database, 1982 - 2021 - Sheet1.csv")

# %%
test = old_data["location"]

# %%
city = []
state = []
for t in test:
    city.append(t.split(",")[0])
    state.append(t.split(", ")[1])

# %%
old_data["state"] = state
old_data["city"] = city
old_data.head()
# Out:
#                                case               location       date  \
# 0             San Jose VTA shooting   San Jose, California  5/26/2021
# 1          FedEx warehouse shooting  Indianapolis, Indiana  4/15/2021
# 2    Orange office complex shooting     Orange, California  3/31/2021
# 3      Boulder supermarket shooting      Boulder, Colorado  3/22/2021
# 4  Atlanta massage parlor shootings       Atlanta, Georgia  3/16/2021
#
#                                              summary  fatalities  injured  \
# 0  Samuel Cassidy, 57, a Valley Transportation Au...           9        0
# 1  Brandon Scott Hole, 19, opened fire around 11 ...           8        7
# 2  Aminadab Gaxiola Gonzalez, 44, allegedly opene...           4        1
# 3  Ahmad Al Aliwi Alissa, 21, carried out a mass ...          10        0
# 4  Robert Aaron Long, 21, killed eight people at ...           8        1
#
#    total_victims location.1 age_of_shooter prior_signs_mental_health_issues  \
# 0              9  Workplace             57                              yes
# 1             15  Workplace             19                              yes
# 2              5  Workplace              -                                -
# 3             10  Workplace             21                              yes
# 4              9  Workplace             21                                -
#
#    ... gender                                            sources  \
# 0  ...      M  https://www.sfchronicle.com/crime/article/Mass...
# 1  ...      M  https://www.indystar.com/story/news/crime/2021...
# 2  ...      M  https://www.latimes.com/california/story/2021-...
# 3  ...      M  https://www.denverpost.com/2021/03/22/police-a...
# 4  ...      M  https://www.ajc.com/news/breaking-multiple-sho...
#
#                                mental_health_sources sources_additional_age  \
# 0  https://www.nytimes.com/2021/05/26/us/what-hap...                      -
# 1  https://www.nytimes.com/2021/04/19/us/indianap...                      -
# 2                                                  -                      -
# 3  https://www.thedailybeast.com/boulder-colorado...                      -
# 4                                                  -                      -
#
#     latitude   longitude   type  year       state          city
# 0  37.316097 -121.888533   Mass  2021  California      San Jose
# 1  39.686630  -86.323130   Mass  2021     Indiana  Indianapolis
# 2  33.835420 -117.853790   Mass  2021  California        Orange
# 3  39.986961 -105.251168   Mass  2021    Colorado       Boulder
# 4  34.111653  -84.580376  Spree  2021     Georgia       Atlanta
#
# [5 rows x 26 columns]

# %%
new_data = old_data[["case","location","date","summary","fatalities","injured","total_victims","location.1","age_of_shooter","prior_signs_mental_health_issues","mental_health_details","weapons_obtained_legally","where_obtained","race","gender","latitude","longitude","type","year","state","city"]]
new_data.head()
# Out:
#                                case               location       date  \
# 0             San Jose VTA shooting   San Jose, California  5/26/2021
# 1          FedEx warehouse shooting  Indianapolis, Indiana  4/15/2021
# 2    Orange office complex shooting     Orange, California  3/31/2021
# 3      Boulder supermarket shooting      Boulder, Colorado  3/22/2021
# 4  Atlanta massage parlor shootings       Atlanta, Georgia  3/16/2021
#
#                                              summary  fatalities  injured  \
# 0  Samuel Cassidy, 57, a Valley Transportation Au...           9        0
# 1  Brandon Scott Hole, 19, opened fire around 11 ...           8        7
# 2  Aminadab Gaxiola Gonzalez, 44, allegedly opene...           4        1
# 3  Ahmad Al Aliwi Alissa, 21, carried out a mass ...          10        0
# 4  Robert Aaron Long, 21, killed eight people at ...           8        1
#
#    total_victims location.1 age_of_shooter prior_signs_mental_health_issues  \
# 0              9  Workplace             57                              yes
# 1             15  Workplace             19                              yes
# 2              5  Workplace              -                                -
# 3             10  Workplace             21                              yes
# 4              9  Workplace             21                                -
#
#    ... weapons_obtained_legally where_obtained   race gender   latitude  \
# 0  ...                        -              -      -      M  37.316097
# 1  ...                      yes              -  White      M  39.686630
# 2  ...                        -              -      -      M  33.835420
# 3  ...                      Yes              -      -      M  39.986961
# 4  ...                        -              -  White      M  34.111653
#
#     longitude   type  year       state          city
# 0 -121.888533   Mass  2021  California      San Jose
# 1  -86.323130   Mass  2021     Indiana  Indianapolis
# 2 -117.853790   Mass  2021  California        Orange
# 3 -105.251168   Mass  2021    Colorado       Boulder
# 4  -84.580376  Spree  2021     Georgia       Atlanta
#
# [5 rows x 21 columns]

# %%
#Categorize the states into their respective regions and put them in a list
west = ["Colorado", "Wyoming", "Montana", "Idaho", "Washington", "Oregon",
                                  "Utah", "Nevada", "California", "Alaska", "Hawaii"]
southwest = ["Texas", "Oklahoma", "New Mexico", "Arizona"]
midwest = ["Ohio", "Indiana", "Michigan", "Illinois", "Missouri", "Wisconsin", "Minnesota",
                                     "Iowa", "Kansas", "Nebraska", "South Dakota", "North Dakota"]
southeast = ["West Virginia", "Virginia", "Kentucky", "Tennessee", "North Carolina",
                                       "South Carolina", "Georgia", "Alabama", "Mississippi", "Arkansas",
                                       "Louisiana", "Florida"] 
northeast = ["Maine", "Massachusetts", "Rhode Island", "Connecticut", "New Hampshire", "Maryland",
                                       "Vermont", "New York", "Pennsylvania", "New Jersey", "Delaware", "D.C"]

# %%
#Create a dataframe for each region
west_df = pd.DataFrame(west, columns = ["state"])
west_df['region'] = "West"

southwest_df = pd.DataFrame(southwest, columns = ["state"])
southwest_df['region'] = "Southwest"

midwest_df = pd.DataFrame(midwest, columns = ["state"])
midwest_df['region'] = "Midwest"

southeast_df = pd.DataFrame(southeast, columns = ["state"])
southeast_df['region'] = "Southeast"

northeast_df = pd.DataFrame(northeast, columns = ["state"])
northeast_df['region'] = "Northeast"

# %%
#Append diff region dataframes into one region indicator dataframe
region_df = west_df.copy()
region_df = region_df.append(southwest_df)
region_df = region_df.append(midwest_df)
region_df = region_df.append(southeast_df)
region_df = region_df.append(northeast_df)
region_df.head()
# Out:
#         state region
# 0    Colorado   West
# 1     Wyoming   West
# 2     Montana   West
# 3       Idaho   West
# 4  Washington   West

# %%
#Merge the region & main dataframe together on 'state' column
merged_df = pd.merge(new_data, region_df, on='state')
merged_df.head()
# Out:
#                                case                   location       date  \
# 0             San Jose VTA shooting       San Jose, California  5/26/2021
# 1    Orange office complex shooting         Orange, California  3/31/2021
# 2   Gilroy garlic festival shooting         Gilroy, California  7/28/2019
# 3  Thousand Oaks nightclub shooting  Thousand Oaks, California  11/7/2018
# 4             T&T Trucking shooting    Bakersfield, California  9/12/2018
#
#                                              summary  fatalities  injured  \
# 0  Samuel Cassidy, 57, a Valley Transportation Au...           9        0
# 1  Aminadab Gaxiola Gonzalez, 44, allegedly opene...           4        1
# 2  Santino William LeGan, 19, fired indiscriminat...           3       12
# 3  Ian David Long, 28, dressed in black and armed...          12       22
# 4  Javier Casarez, 54, who was going through a bi...           5        0
#
#    total_victims location.1 age_of_shooter prior_signs_mental_health_issues  \
# 0              9  Workplace             57                              yes
# 1              5  Workplace              -                                -
# 2             15      Other             19                              TBD
# 3             34      Other             28                              Yes
# 4              5  Workplace             54                                -
#
#    ...              where_obtained    race gender   latitude   longitude  \
# 0  ...                           -       -      M  37.316097 -121.888533
# 1  ...                           -       -      M  33.835420 -117.853790
# 2  ...           Nevada, on July 9       -      M  36.997191 -121.584819
# 3  ...  A gun store in Simi Valley       -      M  34.176946 -118.874793
# 4  ...                           -  Latino      M  35.349388 -118.916335
#
#     type  year       state           city region
# 0   Mass  2021  California       San Jose   West
# 1   Mass  2021  California         Orange   West
# 2   Mass  2019  California         Gilroy   West
# 3   Mass  2018  California  Thousand Oaks   West
# 4  Spree  2018  California    Bakersfield   West
#
# [5 rows x 22 columns]

# %%
#Change column order & remove first location column
new_merged_df = merged_df[["case","city", "state", "region", "date","summary","fatalities","injured","total_victims",
                     "location.1","age_of_shooter","prior_signs_mental_health_issues","mental_health_details",
                     "weapons_obtained_legally","race","gender","latitude","longitude","type","year"]]

# %%
#Change col name of location of shooting to "location"
new_merged_df.rename(columns={'location.1':'location'}, inplace=True)
# Out:
# /Users/carmelamonis/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ### Clean up date

# %%
#Convert date column to a datetime object
new_merged_df['date'] = pd.to_datetime(new_merged_df['date'])
# Out:
# /Users/carmelamonis/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Create a 'month' column by extracting the month from the date column
new_merged_df['month'] = pd.DatetimeIndex(new_merged_df['date']).month

#Change month number to abbreviation
new_merged_df['month'] = new_merged_df['month'].apply(lambda x: calendar.month_abbr[x])
new_merged_df.head()
# Out:
# /Users/carmelamonis/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/carmelamonis/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                case           city       state region  \
# 0             San Jose VTA shooting       San Jose  California   West
# 1    Orange office complex shooting         Orange  California   West
# 2   Gilroy garlic festival shooting         Gilroy  California   West
# 3  Thousand Oaks nightclub shooting  Thousand Oaks  California   West
# 4             T&T Trucking shooting    Bakersfield  California   West
#
#         date                                            summary  fatalities  \
# 0 2021-05-26  Samuel Cassidy, 57, a Valley Transportation Au...           9
# 1 2021-03-31  Aminadab Gaxiola Gonzalez, 44, allegedly opene...           4
# 2 2019-07-28  Santino William LeGan, 19, fired indiscriminat...           3
# 3 2018-11-07  Ian David Long, 28, dressed in black and armed...          12
# 4 2018-09-12  Javier Casarez, 54, who was going through a bi...           5
#
#    injured  total_victims   location  ... prior_signs_mental_health_issues  \
# 0        0              9  Workplace  ...                              yes
# 1        1              5  Workplace  ...                                -
# 2       12             15      Other  ...                              TBD
# 3       22             34      Other  ...                              Yes
# 4        0              5  Workplace  ...                                -
#
#                                mental_health_details weapons_obtained_legally  \
# 0  Perpetrator had a history of depression, angry...                        -
# 1                                                  -                        -
# 2                                                  -                      Yes
# 3  Per the LATimes: "Sheriff Geoff Dean said his ...                      Yes
# 4                                                  -                      Yes
#
#      race gender   latitude   longitude   type  year  month
# 0       -      M  37.316097 -121.888533   Mass  2021    May
# 1       -      M  33.835420 -117.853790   Mass  2021    Mar
# 2       -      M  36.997191 -121.584819   Mass  2019    Jul
# 3       -      M  34.176946 -118.874793   Mass  2018    Nov
# 4  Latino      M  35.349388 -118.916335  Spree  2018    Sep
#
# [5 rows x 21 columns]

# %%
#Sort data by date in descending order
new_merged_df = new_merged_df.sort_values(by='date', ascending=False)

# %%
#Change format of date
new_merged_df['date'] = new_merged_df['date'].dt.strftime('%m/%d/%Y')
new_merged_df.head()
# Out:
#                                 case          city       state     region  \
# 0              San Jose VTA shooting      San Jose  California       West
# 22          FedEx warehouse shooting  Indianapolis     Indiana    Midwest
# 1     Orange office complex shooting        Orange  California       West
# 23      Boulder supermarket shooting       Boulder    Colorado       West
# 30  Atlanta massage parlor shootings       Atlanta     Georgia  Southeast
#
#           date                                            summary  fatalities  \
# 0   05/26/2021  Samuel Cassidy, 57, a Valley Transportation Au...           9
# 22  04/15/2021  Brandon Scott Hole, 19, opened fire around 11 ...           8
# 1   03/31/2021  Aminadab Gaxiola Gonzalez, 44, allegedly opene...           4
# 23  03/22/2021  Ahmad Al Aliwi Alissa, 21, carried out a mass ...          10
# 30  03/16/2021  Robert Aaron Long, 21, killed eight people at ...           8
#
#     injured  total_victims   location  ... prior_signs_mental_health_issues  \
# 0         0              9  Workplace  ...                              yes
# 22        7             15  Workplace  ...                              yes
# 1         1              5  Workplace  ...                                -
# 23        0             10  Workplace  ...                              yes
# 30        1              9  Workplace  ...                                -
#
#                                 mental_health_details  \
# 0   Perpetrator had a history of depression, angry...
# 22  Perpetrator had been reported to police in 202...
# 1                                                   -
# 23  Brother described him as paranoid; multiple ac...
# 30                                                  -
#
#    weapons_obtained_legally   race gender   latitude   longitude   type  year  \
# 0                         -      -      M  37.316097 -121.888533   Mass  2021
# 22                      yes  White      M  39.686630  -86.323130   Mass  2021
# 1                         -      -      M  33.835420 -117.853790   Mass  2021
# 23                      Yes      -      M  39.986961 -105.251168   Mass  2021
# 30                        -  White      M  34.111653  -84.580376  Spree  2021
#
#     month
# 0     May
# 22    Apr
# 1     Mar
# 23    Mar
# 30    Mar
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Update missing values to Unknown

# %%
#Pandas autofilled empty cells w/ a string containg \n. Replace any of those with "Unknown"
new_merged_df.loc[new_merged_df['location'].str.contains('\n'), 'location'] = 'Unknown'

#Update age_of_shooter column
new_merged_df['age_of_shooter'] = new_merged_df['age_of_shooter'].replace({'-': 'Unknown'})

#Update prior_signs_mental_health_issues column
new_merged_df['prior_signs_mental_health_issues'] = new_merged_df['prior_signs_mental_health_issues'].replace({'-': 'Unknown', 
                                                                                                              'TBD': 'Unknown', 'yes':'Yes', 'no': 'No'})

#Update mental_health_details column
new_merged_df['mental_health_details'] = new_merged_df['mental_health_details'].replace({'-': 'Unknown', '(pending)' : 'Unknown'})

#Update weapons_obtained_legally column
new_merged_df['weapons_obtained_legally'] = new_merged_df['weapons_obtained_legally'].replace({'-': 'Unknown', 'TBD' : 'Unknown',
                                           
                                                                                               'yes':'Yes', 'no': 'No'})
new_merged_df.loc[new_merged_df['weapons_obtained_legally'].str.contains('Yes'), 'weapons_obtained_legally'] = 'Yes'

#Replace the one last remaining data to Yes
new_merged_df.loc[(~new_merged_df['weapons_obtained_legally'].str.contains('Yes')) &
                      (~new_merged_df['weapons_obtained_legally'].str.contains('No')) &
                      (~new_merged_df['weapons_obtained_legally'].str.contains('Unknown')), 'weapons_obtained_legally'] = 'Yes'

#Update race column
new_merged_df['race'] = new_merged_df['race'].replace({'-': 'Unknown'}).str.title()

#Update gender column
new_merged_df['gender'] = new_merged_df['gender'].replace({'M': 'Male', 'F' : 'Female'})

new_merged_df.head()
# Out:
#                                 case          city       state     region  \
# 0              San Jose VTA shooting      San Jose  California       West
# 22          FedEx warehouse shooting  Indianapolis     Indiana    Midwest
# 1     Orange office complex shooting        Orange  California       West
# 23      Boulder supermarket shooting       Boulder    Colorado       West
# 30  Atlanta massage parlor shootings       Atlanta     Georgia  Southeast
#
#           date                                            summary  fatalities  \
# 0   05/26/2021  Samuel Cassidy, 57, a Valley Transportation Au...           9
# 22  04/15/2021  Brandon Scott Hole, 19, opened fire around 11 ...           8
# 1   03/31/2021  Aminadab Gaxiola Gonzalez, 44, allegedly opene...           4
# 23  03/22/2021  Ahmad Al Aliwi Alissa, 21, carried out a mass ...          10
# 30  03/16/2021  Robert Aaron Long, 21, killed eight people at ...           8
#
#     injured  total_victims   location  ... prior_signs_mental_health_issues  \
# 0         0              9  Workplace  ...                              Yes
# 22        7             15  Workplace  ...                              Yes
# 1         1              5  Workplace  ...                          Unknown
# 23        0             10  Workplace  ...                              Yes
# 30        1              9  Workplace  ...                          Unknown
#
#                                 mental_health_details  \
# 0   Perpetrator had a history of depression, angry...
# 22  Perpetrator had been reported to police in 202...
# 1                                             Unknown
# 23  Brother described him as paranoid; multiple ac...
# 30                                            Unknown
#
#    weapons_obtained_legally     race gender   latitude   longitude   type  \
# 0                   Unknown  Unknown   Male  37.316097 -121.888533   Mass
# 22                      Yes    White   Male  39.686630  -86.323130   Mass
# 1                   Unknown  Unknown   Male  33.835420 -117.853790   Mass
# 23                      Yes  Unknown   Male  39.986961 -105.251168   Mass
# 30                  Unknown    White   Male  34.111653  -84.580376  Spree
#
#     year  month
# 0   2021    May
# 22  2021    Apr
# 1   2021    Mar
# 23  2021    Mar
# 30  2021    Mar
#
# [5 rows x 21 columns]

# %%
#Rearrange columns
cleaned_df = new_merged_df[['case', 'city', 'state', 'region', 'date', 'summary', 'fatalities',
       'injured', 'total_victims', 'location', 'age_of_shooter',
       'prior_signs_mental_health_issues', 'mental_health_details',
       'weapons_obtained_legally', 'race', 'gender', 'latitude', 'longitude',
       'type','month', 'year']]
cleaned_df = cleaned_df.reset_index(drop=True)
cleaned_df.head()
# Out:
#                                case          city       state     region  \
# 0             San Jose VTA shooting      San Jose  California       West
# 1          FedEx warehouse shooting  Indianapolis     Indiana    Midwest
# 2    Orange office complex shooting        Orange  California       West
# 3      Boulder supermarket shooting       Boulder    Colorado       West
# 4  Atlanta massage parlor shootings       Atlanta     Georgia  Southeast
#
#          date                                            summary  fatalities  \
# 0  05/26/2021  Samuel Cassidy, 57, a Valley Transportation Au...           9
# 1  04/15/2021  Brandon Scott Hole, 19, opened fire around 11 ...           8
# 2  03/31/2021  Aminadab Gaxiola Gonzalez, 44, allegedly opene...           4
# 3  03/22/2021  Ahmad Al Aliwi Alissa, 21, carried out a mass ...          10
# 4  03/16/2021  Robert Aaron Long, 21, killed eight people at ...           8
#
#    injured  total_victims   location  ... prior_signs_mental_health_issues  \
# 0        0              9  Workplace  ...                              Yes
# 1        7             15  Workplace  ...                              Yes
# 2        1              5  Workplace  ...                          Unknown
# 3        0             10  Workplace  ...                              Yes
# 4        1              9  Workplace  ...                          Unknown
#
#                                mental_health_details weapons_obtained_legally  \
# 0  Perpetrator had a history of depression, angry...                  Unknown
# 1  Perpetrator had been reported to police in 202...                      Yes
# 2                                            Unknown                  Unknown
# 3  Brother described him as paranoid; multiple ac...                      Yes
# 4                                            Unknown                  Unknown
#
#       race gender   latitude   longitude   type month  year
# 0  Unknown   Male  37.316097 -121.888533   Mass   May  2021
# 1    White   Male  39.686630  -86.323130   Mass   Apr  2021
# 2  Unknown   Male  33.835420 -117.853790   Mass   Mar  2021
# 3  Unknown   Male  39.986961 -105.251168   Mass   Mar  2021
# 4    White   Male  34.111653  -84.580376  Spree   Mar  2021
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Load dataframe to postgres

# %% [raw]
# #Configure the conection string
# rds_connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
#
# #Confirm connection string
# print(rds_connection_string)
#
# #Connect to the database
# engine = create_engine(rds_connection_string)
# conn = engine.connect()

# %% [raw]
# cleaned_df.to_sql(name='mass_shooting', con=conn, if_exists='append', index=False)
